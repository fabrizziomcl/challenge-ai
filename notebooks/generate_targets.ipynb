# %%
# Celda 1: Imports y configuración de Bedrock y rutas S3
import boto3
import pandas as pd
import json
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm import tqdm

BEDROCK = boto3.client('bedrock-runtime', region_name='us-east-1')
MODEL_ID = 'amazon.nova-micro-v1:0'

S3_BUCKET = 'preauth-challenge-ai-20252'
S3_INPUT = f's3://{S3_BUCKET}/generated_data/credir_risk_reto_generated.csv'
S3_OUTPUT = f's3://{S3_BUCKET}/final_data/credir_risk_reto_classified.csv'

# %%
# Celda 2: Carga del dataset con descripciones
df = pd.read_csv(S3_INPUT)
print(f"Registros cargados: {len(df)}")
print(df.head(3))
# Out:
# Registros cargados: 1000
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
#
#    Duration    Purpose                                        Description
# 0         6   radio/TV  The 67-year-old male customer, employed and re...
# 1        48   radio/TV  The credit risk profile for this 22-year-old f...
# 2        12  education  The credit risk profile for this 49-year-old m...

# %%
# Cell 3: Classification and parallelization function
import time
import random

def classify_credit_risk(description, client, model_id, max_retries=5):
    if not isinstance(description, str) or len(description) < 10:
        return 'error_no_description'
    
    prompt = (
        "Your only task is to classify the provided text. "
        "You must only respond strictly with 'good risk' or 'bad risk'.\n\n"
        f"Description:\n\"{description}\""
    )
    msg = {'role': 'user', 'content': [{'text': prompt}]}
    
    for attempt in range(max_retries):
        try:
            resp = client.converse(
                modelId=model_id,
                messages=[msg],
                inferenceConfig={'maxTokens': 5, 'temperature': 1.0, 'topP': 0.9}
            )
            lbl = resp['output']['message']['content'][0]['text'].strip().lower()
            return lbl if lbl in ('good risk', 'bad risk') else 'error_parsing'
        except Exception as e:
            if 'ThrottlingException' in str(e):
                wait_time = (2 ** attempt) + random.uniform(0, 1)
                print(f"ThrottlingException detectada. Reintentando en {wait_time:.2f} segundos...")
                time.sleep(wait_time)
            else:
                print(f"Error inesperado en la API: {e}")
                return 'error_api_call' 
                
    return 'error_max_retries'

def process_item(pair):
    idx, row = pair
    label = classify_credit_risk(row.Description, BEDROCK, MODEL_ID)
    return idx, label

def classify_parallel(df, workers=10):
    total = len(df)
    print(f"Iniciando clasificación de {total} descripciones en paralelo...")
    labels = [None] * total
    with ThreadPoolExecutor(max_workers=workers) as exe:
        futures = {exe.submit(process_item, item): item[0] for item in df.iterrows()}
        count = 0
        for f in as_completed(futures):
            idx, lbl = f.result()
            labels[idx] = lbl
            count += 1
            if count % 100 == 0 or count == total:
                print(f"  Procesadas {count}/{total}")
    return labels

# %%
df['Target'] = classify_parallel(df, workers=10)
print("Distribución de etiquetas:")
print(df.Target.value_counts())

df.to_csv(S3_OUTPUT, index=False) 

print(f"Archivo final guardado en: {S3_OUTPUT}")
print(f"Filas finales: {len(df)}")
# Out:
# Iniciando clasificación de 1000 descripciones en paralelo...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.95 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 2.61 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.19 segundos...
# ThrottlingException detectada. Reintentando en 2.65 segundos...
# ThrottlingException detectada. Reintentando en 2.58 segundos...
# ThrottlingException detectada. Reintentando en 1.91 segundos...
# ThrottlingException detectada. Reintentando en 2.80 segundos...
# ThrottlingException detectada. Reintentando en 4.57 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 2.35 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 4.36 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 4.39 segundos...
# ThrottlingException detectada. Reintentando en 2.38 segundos...
# ThrottlingException detectada. Reintentando en 4.85 segundos...
# ThrottlingException detectada. Reintentando en 1.27 segundos...
# ThrottlingException detectada. Reintentando en 1.60 segundos...
# ThrottlingException detectada. Reintentando en 1.19 segundos...
# ThrottlingException detectada. Reintentando en 1.58 segundos...
# ThrottlingException detectada. Reintentando en 1.70 segundos...
# ThrottlingException detectada. Reintentando en 1.98 segundos...
# ThrottlingException detectada. Reintentando en 8.86 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 1.71 segundos...
# ThrottlingException detectada. Reintentando en 2.72 segundos...
# ThrottlingException detectada. Reintentando en 2.63 segundos...
# ThrottlingException detectada. Reintentando en 1.40 segundos...
# ThrottlingException detectada. Reintentando en 2.18 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 1.62 segundos...
#   Procesadas 100/1000
# ThrottlingException detectada. Reintentando en 16.51 segundos...
# ThrottlingException detectada. Reintentando en 2.98 segundos...
# ThrottlingException detectada. Reintentando en 1.70 segundos...
# ThrottlingException detectada. Reintentando en 1.81 segundos...
# ThrottlingException detectada. Reintentando en 4.61 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 1.43 segundos...
# ThrottlingException detectada. Reintentando en 2.29 segundos...
# ThrottlingException detectada. Reintentando en 1.06 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 2.90 segundos...
# ThrottlingException detectada. Reintentando en 4.85 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 1.65 segundos...
# ThrottlingException detectada. Reintentando en 1.51 segundos...
# ThrottlingException detectada. Reintentando en 8.48 segundos...
# ThrottlingException detectada. Reintentando en 2.48 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 2.54 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 2.37 segundos...
# ThrottlingException detectada. Reintentando en 1.52 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 4.27 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 1.49 segundos...
# ThrottlingException detectada. Reintentando en 1.87 segundos...
# ThrottlingException detectada. Reintentando en 2.26 segundos...
# ThrottlingException detectada. Reintentando en 2.12 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 1.06 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.88 segundos...
# ThrottlingException detectada. Reintentando en 2.85 segundos...
# ThrottlingException detectada. Reintentando en 1.40 segundos...
# ThrottlingException detectada. Reintentando en 8.68 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.23 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 2.72 segundos...
# ThrottlingException detectada. Reintentando en 2.00 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 1.29 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 2.35 segundos...
# ThrottlingException detectada. Reintentando en 1.33 segundos...
# ThrottlingException detectada. Reintentando en 1.16 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.40 segundos...
# ThrottlingException detectada. Reintentando en 1.06 segundos...
# ThrottlingException detectada. Reintentando en 4.47 segundos...
# ThrottlingException detectada. Reintentando en 2.55 segundos...
# ThrottlingException detectada. Reintentando en 2.37 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 2.95 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 2.13 segundos...
# ThrottlingException detectada. Reintentando en 4.56 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 4.61 segundos...
# ThrottlingException detectada. Reintentando en 4.68 segundos...
# ThrottlingException detectada. Reintentando en 4.84 segundos...
# ThrottlingException detectada. Reintentando en 1.15 segundos...
# ThrottlingException detectada. Reintentando en 2.21 segundos...
# ThrottlingException detectada. Reintentando en 1.56 segundos...
# ThrottlingException detectada. Reintentando en 1.20 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 2.89 segundos...
# ThrottlingException detectada. Reintentando en 4.77 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
#   Procesadas 200/1000
# ThrottlingException detectada. Reintentando en 8.24 segundos...
# ThrottlingException detectada. Reintentando en 2.80 segundos...
# ThrottlingException detectada. Reintentando en 1.09 segundos...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 4.58 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 4.60 segundos...
# ThrottlingException detectada. Reintentando en 2.91 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.54 segundos...
# ThrottlingException detectada. Reintentando en 1.96 segundos...
# ThrottlingException detectada. Reintentando en 1.23 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 2.33 segundos...
# ThrottlingException detectada. Reintentando en 2.25 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
# ThrottlingException detectada. Reintentando en 1.66 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.27 segundos...
# ThrottlingException detectada. Reintentando en 4.52 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 1.82 segundos...
# ThrottlingException detectada. Reintentando en 2.21 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 4.13 segundos...
# ThrottlingException detectada. Reintentando en 2.82 segundos...
# ThrottlingException detectada. Reintentando en 1.37 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 4.30 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 2.98 segundos...
# ThrottlingException detectada. Reintentando en 1.16 segundos...
# ThrottlingException detectada. Reintentando en 1.83 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 1.39 segundos...
# ThrottlingException detectada. Reintentando en 1.19 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 1.62 segundos...
# ThrottlingException detectada. Reintentando en 4.98 segundos...
# ThrottlingException detectada. Reintentando en 2.10 segundos...
# ThrottlingException detectada. Reintentando en 2.45 segundos...
# ThrottlingException detectada. Reintentando en 1.01 segundos...
# ThrottlingException detectada. Reintentando en 1.82 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 2.80 segundos...
# ThrottlingException detectada. Reintentando en 2.80 segundos...
# ThrottlingException detectada. Reintentando en 4.59 segundos...
# ThrottlingException detectada. Reintentando en 2.86 segundos...
# ThrottlingException detectada. Reintentando en 4.57 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 4.73 segundos...
# ThrottlingException detectada. Reintentando en 1.88 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 2.62 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 8.36 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 1.37 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 8.56 segundos...
# ThrottlingException detectada. Reintentando en 2.54 segundos...
# ThrottlingException detectada. Reintentando en 1.48 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 2.11 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 2.18 segundos...
# ThrottlingException detectada. Reintentando en 4.95 segundos...
# ThrottlingException detectada. Reintentando en 16.16 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.16 segundos...
# ThrottlingException detectada. Reintentando en 4.16 segundos...
# ThrottlingException detectada. Reintentando en 1.63 segundos...
# ThrottlingException detectada. Reintentando en 4.43 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.90 segundos...
# ThrottlingException detectada. Reintentando en 8.63 segundos...
# ThrottlingException detectada. Reintentando en 1.39 segundos...
# ThrottlingException detectada. Reintentando en 8.63 segundos...
#   Procesadas 300/1000
# ThrottlingException detectada. Reintentando en 1.49 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 2.01 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 2.47 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 16.22 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 2.20 segundos...
# ThrottlingException detectada. Reintentando en 2.91 segundos...
# ThrottlingException detectada. Reintentando en 4.97 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 4.98 segundos...
# ThrottlingException detectada. Reintentando en 16.47 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 8.16 segundos...
# ThrottlingException detectada. Reintentando en 1.41 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 2.46 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 2.15 segundos...
# ThrottlingException detectada. Reintentando en 4.65 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 1.03 segundos...
# ThrottlingException detectada. Reintentando en 4.16 segundos...
# ThrottlingException detectada. Reintentando en 2.25 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 4.22 segundos...
# ThrottlingException detectada. Reintentando en 4.43 segundos...
# ThrottlingException detectada. Reintentando en 1.70 segundos...
# ThrottlingException detectada. Reintentando en 8.35 segundos...
# ThrottlingException detectada. Reintentando en 2.00 segundos...
# ThrottlingException detectada. Reintentando en 2.01 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 1.48 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 2.97 segundos...
# ThrottlingException detectada. Reintentando en 2.76 segundos...
# ThrottlingException detectada. Reintentando en 2.11 segundos...
# ThrottlingException detectada. Reintentando en 1.16 segundos...
# ThrottlingException detectada. Reintentando en 8.62 segundos...
# ThrottlingException detectada. Reintentando en 2.67 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 2.46 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 4.39 segundos...
# ThrottlingException detectada. Reintentando en 1.29 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.91 segundos...
# ThrottlingException detectada. Reintentando en 1.53 segundos...
# ThrottlingException detectada. Reintentando en 2.87 segundos...
# ThrottlingException detectada. Reintentando en 2.97 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 4.46 segundos...
# ThrottlingException detectada. Reintentando en 1.03 segundos...
# ThrottlingException detectada. Reintentando en 8.78 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 4.89 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 2.03 segundos...
# ThrottlingException detectada. Reintentando en 2.02 segundos...
# ThrottlingException detectada. Reintentando en 1.69 segundos...
# ThrottlingException detectada. Reintentando en 8.07 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 2.27 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 2.20 segundos...
#   Procesadas 400/1000
# ThrottlingException detectada. Reintentando en 1.13 segundos...
# ThrottlingException detectada. Reintentando en 16.51 segundos...
# ThrottlingException detectada. Reintentando en 4.89 segundos...
# ThrottlingException detectada. Reintentando en 4.94 segundos...
# ThrottlingException detectada. Reintentando en 1.61 segundos...
# ThrottlingException detectada. Reintentando en 2.40 segundos...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.70 segundos...
# ThrottlingException detectada. Reintentando en 1.65 segundos...
# ThrottlingException detectada. Reintentando en 1.11 segundos...
# ThrottlingException detectada. Reintentando en 1.19 segundos...
# ThrottlingException detectada. Reintentando en 1.79 segundos...
# ThrottlingException detectada. Reintentando en 1.14 segundos...
# ThrottlingException detectada. Reintentando en 2.41 segundos...
# ThrottlingException detectada. Reintentando en 4.69 segundos...
# ThrottlingException detectada. Reintentando en 8.02 segundos...
# ThrottlingException detectada. Reintentando en 1.16 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 2.84 segundos...
# ThrottlingException detectada. Reintentando en 2.54 segundos...
# ThrottlingException detectada. Reintentando en 1.37 segundos...
# ThrottlingException detectada. Reintentando en 1.00 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 8.09 segundos...
# ThrottlingException detectada. Reintentando en 2.57 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 4.71 segundos...
# ThrottlingException detectada. Reintentando en 16.78 segundos...
# ThrottlingException detectada. Reintentando en 1.62 segundos...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 16.15 segundos...
# ThrottlingException detectada. Reintentando en 4.21 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 2.48 segundos...
# ThrottlingException detectada. Reintentando en 8.58 segundos...
# ThrottlingException detectada. Reintentando en 4.83 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 1.14 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 1.06 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 2.23 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.41 segundos...
# ThrottlingException detectada. Reintentando en 1.06 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 1.90 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 1.91 segundos...
# ThrottlingException detectada. Reintentando en 4.95 segundos...
# ThrottlingException detectada. Reintentando en 2.29 segundos...
# ThrottlingException detectada. Reintentando en 2.15 segundos...
# ThrottlingException detectada. Reintentando en 1.63 segundos...
# ThrottlingException detectada. Reintentando en 2.70 segundos...
# ThrottlingException detectada. Reintentando en 1.81 segundos...
# ThrottlingException detectada. Reintentando en 1.80 segundos...
# ThrottlingException detectada. Reintentando en 2.92 segundos...
# ThrottlingException detectada. Reintentando en 4.91 segundos...
# ThrottlingException detectada. Reintentando en 1.69 segundos...
# ThrottlingException detectada. Reintentando en 1.15 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 8.15 segundos...
# ThrottlingException detectada. Reintentando en 1.65 segundos...
# ThrottlingException detectada. Reintentando en 2.30 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 8.96 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.87 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.65 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 4.68 segundos...
# ThrottlingException detectada. Reintentando en 1.89 segundos...
# ThrottlingException detectada. Reintentando en 1.66 segundos...
#   Procesadas 500/1000
# ThrottlingException detectada. Reintentando en 2.78 segundos...
# ThrottlingException detectada. Reintentando en 1.56 segundos...
# ThrottlingException detectada. Reintentando en 2.77 segundos...
# ThrottlingException detectada. Reintentando en 1.09 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 2.80 segundos...
# ThrottlingException detectada. Reintentando en 2.50 segundos...
# ThrottlingException detectada. Reintentando en 2.61 segundos...
# ThrottlingException detectada. Reintentando en 2.65 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 4.75 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 4.26 segundos...
# ThrottlingException detectada. Reintentando en 2.37 segundos...
# ThrottlingException detectada. Reintentando en 4.88 segundos...
# ThrottlingException detectada. Reintentando en 1.40 segundos...
# ThrottlingException detectada. Reintentando en 1.74 segundos...
# ThrottlingException detectada. Reintentando en 2.18 segundos...
# ThrottlingException detectada. Reintentando en 2.50 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 4.25 segundos...
# ThrottlingException detectada. Reintentando en 2.49 segundos...
# ThrottlingException detectada. Reintentando en 2.67 segundos...
# ThrottlingException detectada. Reintentando en 8.08 segundos...
# ThrottlingException detectada. Reintentando en 2.64 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 2.44 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.88 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 2.00 segundos...
# ThrottlingException detectada. Reintentando en 8.18 segundos...
# ThrottlingException detectada. Reintentando en 16.27 segundos...
# ThrottlingException detectada. Reintentando en 4.08 segundos...
# ThrottlingException detectada. Reintentando en 4.39 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 2.01 segundos...
# ThrottlingException detectada. Reintentando en 4.10 segundos...
# ThrottlingException detectada. Reintentando en 2.14 segundos...
# ThrottlingException detectada. Reintentando en 2.96 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 16.87 segundos...
# ThrottlingException detectada. Reintentando en 1.20 segundos...
# ThrottlingException detectada. Reintentando en 1.66 segundos...
# ThrottlingException detectada. Reintentando en 2.28 segundos...
# ThrottlingException detectada. Reintentando en 1.11 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 1.24 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 1.77 segundos...
# ThrottlingException detectada. Reintentando en 2.85 segundos...
# ThrottlingException detectada. Reintentando en 1.71 segundos...
# ThrottlingException detectada. Reintentando en 4.11 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 2.60 segundos...
# ThrottlingException detectada. Reintentando en 1.68 segundos...
# ThrottlingException detectada. Reintentando en 1.91 segundos...
# ThrottlingException detectada. Reintentando en 1.98 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
# ThrottlingException detectada. Reintentando en 1.62 segundos...
# ThrottlingException detectada. Reintentando en 8.11 segundos...
# ThrottlingException detectada. Reintentando en 2.36 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 4.34 segundos...
# ThrottlingException detectada. Reintentando en 2.67 segundos...
# ThrottlingException detectada. Reintentando en 1.79 segundos...
# ThrottlingException detectada. Reintentando en 2.84 segundos...
# ThrottlingException detectada. Reintentando en 1.54 segundos...
# ThrottlingException detectada. Reintentando en 2.60 segundos...
# ThrottlingException detectada. Reintentando en 1.17 segundos...
# ThrottlingException detectada. Reintentando en 1.73 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.63 segundos...
# ThrottlingException detectada. Reintentando en 4.89 segundos...
# ThrottlingException detectada. Reintentando en 2.15 segundos...
# ThrottlingException detectada. Reintentando en 16.97 segundos...
# ThrottlingException detectada. Reintentando en 2.63 segundos...
# ThrottlingException detectada. Reintentando en 1.24 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
#   Procesadas 600/1000
# ThrottlingException detectada. Reintentando en 2.48 segundos...
# ThrottlingException detectada. Reintentando en 1.39 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
# ThrottlingException detectada. Reintentando en 4.77 segundos...
# ThrottlingException detectada. Reintentando en 2.04 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 2.43 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.71 segundos...
# ThrottlingException detectada. Reintentando en 2.69 segundos...
# ThrottlingException detectada. Reintentando en 2.00 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 1.54 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 1.79 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 1.38 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 1.60 segundos...
# ThrottlingException detectada. Reintentando en 1.37 segundos...
# ThrottlingException detectada. Reintentando en 1.79 segundos...
# ThrottlingException detectada. Reintentando en 2.87 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 2.88 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 2.58 segundos...
# ThrottlingException detectada. Reintentando en 2.97 segundos...
# ThrottlingException detectada. Reintentando en 1.74 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 2.82 segundos...
# ThrottlingException detectada. Reintentando en 2.91 segundos...
# ThrottlingException detectada. Reintentando en 2.57 segundos...
# ThrottlingException detectada. Reintentando en 1.23 segundos...
# ThrottlingException detectada. Reintentando en 1.74 segundos...
# ThrottlingException detectada. Reintentando en 2.63 segundos...
# ThrottlingException detectada. Reintentando en 2.17 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 4.37 segundos...
# ThrottlingException detectada. Reintentando en 4.31 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 2.05 segundos...
# ThrottlingException detectada. Reintentando en 1.52 segundos...
# ThrottlingException detectada. Reintentando en 1.20 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 4.81 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 8.42 segundos...
# ThrottlingException detectada. Reintentando en 4.88 segundos...
# ThrottlingException detectada. Reintentando en 1.20 segundos...
# ThrottlingException detectada. Reintentando en 8.32 segundos...
# ThrottlingException detectada. Reintentando en 1.61 segundos...
# ThrottlingException detectada. Reintentando en 1.74 segundos...
# ThrottlingException detectada. Reintentando en 1.15 segundos...
# ThrottlingException detectada. Reintentando en 1.96 segundos...
# ThrottlingException detectada. Reintentando en 1.87 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 16.06 segundos...
# ThrottlingException detectada. Reintentando en 1.95 segundos...
# ThrottlingException detectada. Reintentando en 2.97 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 2.20 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 2.64 segundos...
# ThrottlingException detectada. Reintentando en 1.40 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 1.51 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.43 segundos...
# ThrottlingException detectada. Reintentando en 1.34 segundos...
# ThrottlingException detectada. Reintentando en 4.28 segundos...
# ThrottlingException detectada. Reintentando en 2.41 segundos...
# ThrottlingException detectada. Reintentando en 1.53 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 2.02 segundos...
# ThrottlingException detectada. Reintentando en 2.28 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 4.91 segundos...
# ThrottlingException detectada. Reintentando en 2.57 segundos...
# ThrottlingException detectada. Reintentando en 4.53 segundos...
# ThrottlingException detectada. Reintentando en 4.90 segundos...
#   Procesadas 700/1000
# ThrottlingException detectada. Reintentando en 1.71 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.61 segundos...
# ThrottlingException detectada. Reintentando en 1.25 segundos...
# ThrottlingException detectada. Reintentando en 8.37 segundos...
# ThrottlingException detectada. Reintentando en 1.05 segundos...
# ThrottlingException detectada. Reintentando en 8.42 segundos...
# ThrottlingException detectada. Reintentando en 2.91 segundos...
# ThrottlingException detectada. Reintentando en 1.29 segundos...
# ThrottlingException detectada. Reintentando en 2.25 segundos...
# ThrottlingException detectada. Reintentando en 2.35 segundos...
# ThrottlingException detectada. Reintentando en 1.95 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 4.64 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 1.65 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 4.49 segundos...
# ThrottlingException detectada. Reintentando en 1.96 segundos...
# ThrottlingException detectada. Reintentando en 2.51 segundos...
# ThrottlingException detectada. Reintentando en 2.23 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.31 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.80 segundos...
# ThrottlingException detectada. Reintentando en 1.01 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.01 segundos...
# ThrottlingException detectada. Reintentando en 2.40 segundos...
# ThrottlingException detectada. Reintentando en 2.63 segundos...
# ThrottlingException detectada. Reintentando en 4.56 segundos...
# ThrottlingException detectada. Reintentando en 2.94 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 1.15 segundos...
# ThrottlingException detectada. Reintentando en 4.90 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 2.64 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 1.96 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.83 segundos...
# ThrottlingException detectada. Reintentando en 2.36 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.81 segundos...
# ThrottlingException detectada. Reintentando en 1.89 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 2.95 segundos...
# ThrottlingException detectada. Reintentando en 2.38 segundos...
# ThrottlingException detectada. Reintentando en 1.17 segundos...
# ThrottlingException detectada. Reintentando en 4.87 segundos...
# ThrottlingException detectada. Reintentando en 1.68 segundos...
# ThrottlingException detectada. Reintentando en 4.83 segundos...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 4.44 segundos...
# ThrottlingException detectada. Reintentando en 8.15 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 2.10 segundos...
# ThrottlingException detectada. Reintentando en 8.45 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.14 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 4.79 segundos...
# ThrottlingException detectada. Reintentando en 1.90 segundos...
# ThrottlingException detectada. Reintentando en 1.63 segundos...
# ThrottlingException detectada. Reintentando en 1.73 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.42 segundos...
# ThrottlingException detectada. Reintentando en 2.30 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 2.29 segundos...
# ThrottlingException detectada. Reintentando en 2.49 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 2.47 segundos...
# ThrottlingException detectada. Reintentando en 2.67 segundos...
# ThrottlingException detectada. Reintentando en 2.62 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 1.75 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 1.92 segundos...
# ThrottlingException detectada. Reintentando en 1.92 segundos...
# ThrottlingException detectada. Reintentando en 4.83 segundos...
# ThrottlingException detectada. Reintentando en 2.65 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 4.16 segundos...
#   Procesadas 800/1000
# ThrottlingException detectada. Reintentando en 1.90 segundos...
# ThrottlingException detectada. Reintentando en 2.04 segundos...
# ThrottlingException detectada. Reintentando en 2.18 segundos...
# ThrottlingException detectada. Reintentando en 4.37 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 2.39 segundos...
# ThrottlingException detectada. Reintentando en 2.35 segundos...
# ThrottlingException detectada. Reintentando en 1.20 segundos...
# ThrottlingException detectada. Reintentando en 8.97 segundos...
# ThrottlingException detectada. Reintentando en 2.57 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 1.77 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 4.87 segundos...
# ThrottlingException detectada. Reintentando en 2.98 segundos...
# ThrottlingException detectada. Reintentando en 1.66 segundos...
# ThrottlingException detectada. Reintentando en 1.04 segundos...
# ThrottlingException detectada. Reintentando en 1.45 segundos...
# ThrottlingException detectada. Reintentando en 8.18 segundos...
# ThrottlingException detectada. Reintentando en 1.17 segundos...
# ThrottlingException detectada. Reintentando en 2.63 segundos...
# ThrottlingException detectada. Reintentando en 1.56 segundos...
# ThrottlingException detectada. Reintentando en 2.18 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 2.30 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.50 segundos...
# ThrottlingException detectada. Reintentando en 1.37 segundos...
# ThrottlingException detectada. Reintentando en 2.72 segundos...
# ThrottlingException detectada. Reintentando en 1.11 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 1.26 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 1.29 segundos...
# ThrottlingException detectada. Reintentando en 1.10 segundos...
# ThrottlingException detectada. Reintentando en 2.50 segundos...
# ThrottlingException detectada. Reintentando en 4.92 segundos...
# ThrottlingException detectada. Reintentando en 1.44 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 1.27 segundos...
# ThrottlingException detectada. Reintentando en 2.55 segundos...
# ThrottlingException detectada. Reintentando en 2.77 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 1.31 segundos...
# ThrottlingException detectada. Reintentando en 1.18 segundos...
# ThrottlingException detectada. Reintentando en 2.05 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 2.71 segundos...
# ThrottlingException detectada. Reintentando en 4.78 segundos...
# ThrottlingException detectada. Reintentando en 1.54 segundos...
# ThrottlingException detectada. Reintentando en 2.97 segundos...
# ThrottlingException detectada. Reintentando en 2.53 segundos...
# ThrottlingException detectada. Reintentando en 2.74 segundos...
# ThrottlingException detectada. Reintentando en 1.11 segundos...
# ThrottlingException detectada. Reintentando en 8.47 segundos...
# ThrottlingException detectada. Reintentando en 1.03 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 1.59 segundos...
# ThrottlingException detectada. Reintentando en 4.20 segundos...
# ThrottlingException detectada. Reintentando en 1.60 segundos...
# ThrottlingException detectada. Reintentando en 4.43 segundos...
# ThrottlingException detectada. Reintentando en 1.86 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.74 segundos...
# ThrottlingException detectada. Reintentando en 2.11 segundos...
# ThrottlingException detectada. Reintentando en 1.81 segundos...
# ThrottlingException detectada. Reintentando en 8.48 segundos...
# ThrottlingException detectada. Reintentando en 1.49 segundos...
# ThrottlingException detectada. Reintentando en 1.17 segundos...
# ThrottlingException detectada. Reintentando en 1.27 segundos...
# ThrottlingException detectada. Reintentando en 2.47 segundos...
# ThrottlingException detectada. Reintentando en 2.07 segundos...
# ThrottlingException detectada. Reintentando en 1.07 segundos...
# ThrottlingException detectada. Reintentando en 4.52 segundos...
# ThrottlingException detectada. Reintentando en 4.04 segundos...
# ThrottlingException detectada. Reintentando en 2.42 segundos...
# ThrottlingException detectada. Reintentando en 1.61 segundos...
# ThrottlingException detectada. Reintentando en 2.94 segundos...
# ThrottlingException detectada. Reintentando en 2.88 segundos...
# ThrottlingException detectada. Reintentando en 1.67 segundos...
# ThrottlingException detectada. Reintentando en 8.55 segundos...
# ThrottlingException detectada. Reintentando en 2.00 segundos...
# ThrottlingException detectada. Reintentando en 1.35 segundos...
# ThrottlingException detectada. Reintentando en 1.24 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 4.85 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 2.64 segundos...
# ThrottlingException detectada. Reintentando en 1.02 segundos...
#   Procesadas 900/1000
# ThrottlingException detectada. Reintentando en 1.79 segundos...
# ThrottlingException detectada. Reintentando en 1.27 segundos...
# ThrottlingException detectada. Reintentando en 2.03 segundos...
# ThrottlingException detectada. Reintentando en 1.72 segundos...
# ThrottlingException detectada. Reintentando en 1.51 segundos...
# ThrottlingException detectada. Reintentando en 1.77 segundos...
# ThrottlingException detectada. Reintentando en 2.45 segundos...
# ThrottlingException detectada. Reintentando en 1.47 segundos...
# ThrottlingException detectada. Reintentando en 1.08 segundos...
# ThrottlingException detectada. Reintentando en 1.33 segundos...
# ThrottlingException detectada. Reintentando en 1.33 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 2.52 segundos...
# ThrottlingException detectada. Reintentando en 2.75 segundos...
# ThrottlingException detectada. Reintentando en 4.69 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 2.60 segundos...
# ThrottlingException detectada. Reintentando en 2.36 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 1.46 segundos...
# ThrottlingException detectada. Reintentando en 1.03 segundos...
# ThrottlingException detectada. Reintentando en 8.58 segundos...
# ThrottlingException detectada. Reintentando en 1.33 segundos...
# ThrottlingException detectada. Reintentando en 2.86 segundos...
# ThrottlingException detectada. Reintentando en 4.11 segundos...
# ThrottlingException detectada. Reintentando en 1.36 segundos...
# ThrottlingException detectada. Reintentando en 1.76 segundos...
# ThrottlingException detectada. Reintentando en 1.11 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 1.21 segundos...
# ThrottlingException detectada. Reintentando en 1.68 segundos...
# ThrottlingException detectada. Reintentando en 2.73 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 4.54 segundos...
# ThrottlingException detectada. Reintentando en 2.84 segundos...
# ThrottlingException detectada. Reintentando en 2.43 segundos...
# ThrottlingException detectada. Reintentando en 1.38 segundos...
# ThrottlingException detectada. Reintentando en 1.99 segundos...
# ThrottlingException detectada. Reintentando en 4.88 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 4.66 segundos...
# ThrottlingException detectada. Reintentando en 1.30 segundos...
# ThrottlingException detectada. Reintentando en 2.98 segundos...
# ThrottlingException detectada. Reintentando en 1.84 segundos...
# ThrottlingException detectada. Reintentando en 1.89 segundos...
# ThrottlingException detectada. Reintentando en 2.50 segundos...
# ThrottlingException detectada. Reintentando en 8.33 segundos...
# ThrottlingException detectada. Reintentando en 2.87 segundos...
# ThrottlingException detectada. Reintentando en 4.74 segundos...
# ThrottlingException detectada. Reintentando en 1.22 segundos...
# ThrottlingException detectada. Reintentando en 1.83 segundos...
# ThrottlingException detectada. Reintentando en 1.57 segundos...
# ThrottlingException detectada. Reintentando en 1.78 segundos...
# ThrottlingException detectada. Reintentando en 1.97 segundos...
# ThrottlingException detectada. Reintentando en 1.70 segundos...
# ThrottlingException detectada. Reintentando en 2.10 segundos...
# ThrottlingException detectada. Reintentando en 1.88 segundos...
# ThrottlingException detectada. Reintentando en 16.16 segundos...
# ThrottlingException detectada. Reintentando en 1.58 segundos...
# ThrottlingException detectada. Reintentando en 1.49 segundos...
# ThrottlingException detectada. Reintentando en 2.28 segundos...
# ThrottlingException detectada. Reintentando en 2.39 segundos...
# ThrottlingException detectada. Reintentando en 2.32 segundos...
# ThrottlingException detectada. Reintentando en 1.55 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 1.64 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 4.85 segundos...
# ThrottlingException detectada. Reintentando en 4.50 segundos...
# ThrottlingException detectada. Reintentando en 2.59 segundos...
# ThrottlingException detectada. Reintentando en 1.68 segundos...
# ThrottlingException detectada. Reintentando en 1.51 segundos...
# ThrottlingException detectada. Reintentando en 2.61 segundos...
# ThrottlingException detectada. Reintentando en 1.85 segundos...
# ThrottlingException detectada. Reintentando en 8.79 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 2.11 segundos...
# ThrottlingException detectada. Reintentando en 1.12 segundos...
# ThrottlingException detectada. Reintentando en 1.94 segundos...
# ThrottlingException detectada. Reintentando en 1.88 segundos...
# ThrottlingException detectada. Reintentando en 8.22 segundos...
# ThrottlingException detectada. Reintentando en 1.93 segundos...
# ThrottlingException detectada. Reintentando en 2.10 segundos...
# ThrottlingException detectada. Reintentando en 1.32 segundos...
# ThrottlingException detectada. Reintentando en 1.56 segundos...
# ThrottlingException detectada. Reintentando en 1.15 segundos...
# ThrottlingException detectada. Reintentando en 2.10 segundos...
# ThrottlingException detectada. Reintentando en 16.27 segundos...
#   Procesadas 1000/1000
# Distribución de etiquetas:
# Target
# good risk            640
# bad risk             347
# error_max_retries     13
# Name: count, dtype: int64
# Archivo final guardado en: s3://preauth-challenge-ai-20252/final_data/credir_risk_reto_classified.csv
# Filas finales: 1000

# %%
df
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
#      Duration              Purpose  \
# 0           6             radio/TV
# 1          48             radio/TV
# 2          12            education
# 3          42  furniture/equipment
# 4          24                  car
# ..        ...                  ...
# 995        12  furniture/equipment
# 996        30                  car
# 997        12             radio/TV
# 998        45             radio/TV
# 999        45                  car
#
#                                            Description     Target
# 0    The 67-year-old male customer, employed and re...  good risk
# 1    The credit risk profile for this 22-year-old f...   bad risk
# 2    The credit risk profile for this 49-year-old m...   bad risk
# 3    The 45-year-old male customer, employed in a s...   bad risk
# 4    The 53-year-old skilled male, with limited sav...   bad risk
# ..                                                 ...        ...
# 995  The credit risk profile for this 31-year-old f...   bad risk
# 996  The credit risk profile for this 40-year-old m...   bad risk
# 997  The credit risk profile for this 38-year-old s...  good risk
# 998  The credit risk profile for this 23-year-old m...  good risk
# 999  The credit risk profile for this 27-year-old m...  good risk
#
# [1000 rows x 11 columns]
